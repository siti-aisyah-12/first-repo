# %% [markdown]
# <img src="images/cads-logo.png" style="height: 100px;" align=left>

# %% [markdown]
# # DA Capstone

# %% [markdown]
# 1. Create a team (2-3 people)
# 2. Perform the following:
#     1. **Data Wrangling - Cleaning & Merging**: Check and handle the existance of missing values, the type of variables, or integrity of data
#     2. **Exploratory Data Analysis**: Analyze data to summarize their main characteristics
#     3. **Feature Engineering**: Make new features or change the current features
#     4. **Feature Selection**: Choose the best features
#     5. **Queries** Use SQL to query the data

# %% [markdown]
# ## Submission Guideline
# The output expected at the end of this hackathon is:
# 1. One **Jupyter notebook** containing all analysis performed using Python.
# 2. One **PowerPoint** presentation containing the analysis results. Each group will be allocated 15-20 minutes (inclusive of Q&A) to present their analysis results to the class.
# 3. One **Final Dataset** - in csv format
#
# One zip file per group is to be uploaded on GDrive **by 2:30 pm of the last day**, including the jupyter notebook(s) and the powerpoint presentation indicating the names of all group members.
#
#
# ## Presentation Guideline
#
#
# **Note(s):**
# 1. Only **one submission** is required per group.
# 2. Include full details in your notebook and **report only important results** in your presentation.
# 3. Please only use Jupyter notebook (pandas) to clean the data (Do not clean manually using Excel)

# %% [markdown]
# ## Objective
# **Perform Exploratory Data Analysis for the Dataset Provided uisng Python, then load the data into a database using pandas and Solve the queries. The dataset is about customer purchasing history, and focused on determining potential customers.**
#
# You have been provided with information such as customers spending for last several years, the amount of money spent,Number of inactive months and so on

# %% [markdown]
# ## Data description
# - Below is the description of each feature available in the dataset
# <img src="images/MicrosoftTeams-image.png" style="height: 700px">

# %% [markdown]
# ##  Import necessary Packages

# %%
# Importing relevant packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

#Your Code Here

# %% [markdown]
# ### Load the Data into Pandas Dataframe

# %%
# Load the data into data dataframe
#Your Code Here
df = pd.read_csv(r'C:\Users\Home\Desktop\Apprenticeship Transition Program\Project\data.csv')

# %%
# View first 5 rows of the dataframe
#Your Code Here
df.head(5)
# Out:
#    Potential_Customer    C_ID Cust_Last_Purchase  Pur_3_years  Pur_5_years  \
# 0                   1    9946             $5.00             2           17
# 1                   1   87939            $30.00             1            7
# 2                   0   88003                NaN            5           12
# 3                   1  188721            $20.00             1           11
# 4                   1   88056             $5.00             3           15
#
#    Pur_3_years_Indirect  Pur_5_years_Indirect Pur_latest Pur_3_years_Avg  \
# 0                     2                     4     $0.00           $7.50
# 1                     0                     3    $25.00          $25.00
# 2                     3                     5    $15.00          $15.00
# 3                     0                     3    $20.00          $20.00
# 4                     2                     7     $3.00           $4.33
#
#   Pur_5_years_Avg  ... Ad_Res_5_Year  Ad_Res_Ind_1_Year  Ad_Res_Ind_3_Year  \
# ...

# %%
# View your data
#Your Code Here
df
# Out:
#       Potential_Customer    C_ID Cust_Last_Purchase  Pur_3_years  Pur_5_years  \
# 0                      1    9946             $5.00             2           17
# 1                      1   87939            $30.00             1            7
# 2                      0   88003                NaN            5           12
# 3                      1  188721            $20.00             1           11
# 4                      1   88056             $5.00             3           15
# ...                  ...     ...                ...          ...          ...
# 4464                   1  103926             $5.00             5           24
# 4465                   1  103920             $5.00             4            7
# 4466                   1  114820            $10.00             5           17
# 4467                   1  103953             $5.00             4           19
# 4468                   0  103979                NaN            3            4
#
# ...

# %% [markdown]
# # <font color=green>Data Cleaning<font>
# Checking the existance of missing values, the type of variables, or integrity of data.

# %% [markdown]
# ### How big is the dataset? (number of rows, features and total datapoints)

# %%
#Your Code Here
#Number of rows
print("The number of rows are", len(df))
# Out:
# The number of rows are 4469

# %%
print("The number of features are", len(df.columns))
# Out:
# The number of features are 25

# %%
print("The total datapoints are", df.size)
# Out:
# The total datapoints are 111725

# %% [markdown]
# ### What columns do we have?

# %%
#Your Code Here
df.columns
# Out:
# Index(['Potential_Customer', 'C_ID', 'Cust_Last_Purchase', 'Pur_3_years',
#        'Pur_5_years', 'Pur_3_years_Indirect', 'Pur_5_years_Indirect',
#        'Pur_latest', 'Pur_3_years_Avg', 'Pur_5_years_Avg',
#        'Pur_3_years_Avg_Indirect', 'InAct_Last', 'InAct_First',
#        'Ad_Res_1_year', 'Ad_Res_3_Year', 'Ad_Res_5_Year', 'Ad_Res_Ind_1_Year',
#        'Ad_Res_Ind_3_Year', 'Ad_Res_Ind_5_Year', 'Status_Cust',
#        'Status_Latest_Ad', 'Age', 'Gender', 'Cust_Prop', 'Cust_Ann_Income'],
#       dtype='object')

# %% [markdown]
# ### What is the type of each column?

# %%
#Your Code Here
df.dtypes
# Out:
# Potential_Customer            int64
# C_ID                          int64
# Cust_Last_Purchase           object
# Pur_3_years                   int64
# Pur_5_years                   int64
# Pur_3_years_Indirect          int64
# Pur_5_years_Indirect          int64
# Pur_latest                   object
# Pur_3_years_Avg              object
# Pur_5_years_Avg              object
# Pur_3_years_Avg_Indirect     object
# InAct_Last                    int64
# InAct_First                   int64
# Ad_Res_1_year                 int64
# Ad_Res_3_Year                 int64
# Ad_Res_5_Year                 int64
# Ad_Res_Ind_1_Year             int64
# Ad_Res_Ind_3_Year             int64
# Ad_Res_Ind_5_Year             int64
# Status_Cust                  object
# Status_Latest_Ad              int64
# Age                         float64
# Gender                       object
# Cust_Prop                    object
# Cust_Ann_Income              object
# dtype: object

# %% [markdown]
# ### Why columns such as `Cust_Last_Purchase` are `object` while they should be `float64`?
#
# #### Notice Some features have Dollar AND Comma. Remove the dollar sign and comma from these features
#
# **Hint:** You can use `df.col=df.col.str.replace('OldSign', 'NewSign')`

# %%
#Your Code Here
#There are few features where the type should be float but being identified as object due to there are dollar sign and comma in the dataset

#Before
df['Cust_Last_Purchase']
# Out:
# 0        $5.00
# 1       $30.00
# 2           NaN
# 3       $20.00
# 4        $5.00
#          ...
# 4464     $5.00
# 4465     $5.00
# 4466    $10.00
# 4467     $5.00
# 4468        NaN
# Name: Cust_Last_Purchase, Length: 4469, dtype: object

# %%
#After
df.Cust_Last_Purchase = df.Cust_Last_Purchase.str.replace(',','').str.replace('$','').astype(float)
df.Cust_Last_Purchase
# Out:
# 0        5.0
# 1       30.0
# 2        NaN
# 3       20.0
# 4        5.0
#         ...
# 4464     5.0
# 4465     5.0
# 4466    10.0
# 4467     5.0
# 4468     NaN
# Name: Cust_Last_Purchase, Length: 4469, dtype: float64

# %% [markdown]
# ### Check data for duplicate rows

# %%
# Is there any duplicate in the data
#Your Code Here

#df[df.duplicated()]
print(df.duplicated()) #True is duplicate row
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4464     True
# 4465     True
# 4466     True
# 4467     True
# 4468     True
# Length: 4469, dtype: bool

# %%
# Find the number of duplicates
#Your Code Here
print("The total number of duplicates are", df.duplicated().sum())
# Out:
# The total number of duplicates are 851

# %% [markdown]
# ### Remove duplicate rows
# **Hint:** Use `df=df.drop_duplicates()`

# %%
# Remove duplicates
#Your Code Here
df = df.drop_duplicates()

# %% [markdown]
# ### Do we need `C_ID` in our analysis?

# %%
#Your Code Here
#We didn't need C_ID column in our dataset because this feature dosn't give any inportant information in our analysis
del df["C_ID"]

# %% [markdown]
# ### Check whether the columns' types are accurate? if not handle them

# %%
#Your Code Here
df.dtypes
# Out:
# Potential_Customer            int64
# Cust_Last_Purchase          float64
# Pur_3_years                   int64
# Pur_5_years                   int64
# Pur_3_years_Indirect          int64
# Pur_5_years_Indirect          int64
# Pur_latest                   object
# Pur_3_years_Avg              object
# Pur_5_years_Avg              object
# Pur_3_years_Avg_Indirect     object
# InAct_Last                    int64
# InAct_First                   int64
# Ad_Res_1_year                 int64
# Ad_Res_3_Year                 int64
# Ad_Res_5_Year                 int64
# Ad_Res_Ind_1_Year             int64
# Ad_Res_Ind_3_Year             int64
# Ad_Res_Ind_5_Year             int64
# Status_Cust                  object
# Status_Latest_Ad              int64
# Age                         float64
# Gender                       object
# Cust_Prop                    object
# Cust_Ann_Income              object
# dtype: object

# %%
# The columns type for Pur_latest, Pur_3_years_Avg, Pur_5_years_Avg, Pur_3_years_Avg_Indirect, Cust_Ann_Income are not accurate (object to float)
# Amount, number should be in float

df.Pur_latest = df.Pur_latest.str.replace('$','').astype(float)
df.Pur_3_years_Avg = df.Pur_3_years_Avg.str.replace('$','').astype(float)
df.Pur_5_years_Avg = df.Pur_5_years_Avg.str.replace('$','').astype(float)
df.Pur_3_years_Avg_Indirect = df.Pur_3_years_Avg_Indirect.str.replace('$','').astype(float)
df.Cust_Ann_Income = df.Cust_Ann_Income.str.replace('$','').str.replace(',','').astype(float)

# %%
df.dtypes
# Out:
# Potential_Customer            int64
# Cust_Last_Purchase          float64
# Pur_3_years                   int64
# Pur_5_years                   int64
# Pur_3_years_Indirect          int64
# Pur_5_years_Indirect          int64
# Pur_latest                  float64
# Pur_3_years_Avg             float64
# Pur_5_years_Avg             float64
# Pur_3_years_Avg_Indirect    float64
# InAct_Last                    int64
# InAct_First                   int64
# Ad_Res_1_year                 int64
# Ad_Res_3_Year                 int64
# Ad_Res_5_Year                 int64
# Ad_Res_Ind_1_Year             int64
# Ad_Res_Ind_3_Year             int64
# Ad_Res_Ind_5_Year             int64
# Status_Cust                  object
# Status_Latest_Ad              int64
# Age                         float64
# Gender                       object
# Cust_Prop                    object
# Cust_Ann_Income             float64
# dtype: object

# %% [markdown]
# # <font color=green>Exploratory Data Analysis (EDA)<font>
# Checking the relationship of variables, summary of data, outliers, filling missing values etc.

# %% [markdown]
# ## Explore Categorical Variables

# %%
#Your Code Here

# Nominal : Features where the categories are only labeled without any order or precedence
#         : Potential_Customer, Status_Cust, Status_Latest_Ad, Cust_Prop, Gender

# Ordinal : Feature which have some order associated with them

# Continuous : Numeric variables that have an infinite number of values between any two values
#            : Amount price, No. of ..., Age

# %%
numerical = ['Cust_Last_Purchase', 'Pur_3_years', 'Pur_5_years', 'Pur_3_years_Indirect', 'Pur_5_years_Indirect', 'Pur_latest', 'Pur_3_years_Avg', 'Pur_5_years_Avg', 'Pur_3_years_Avg_Indirect', 'InAct_Last', 'InAct_First', 'Ad_Res_1_year', 'Ad_Res_3_Year', 'Ad_Res_5_Year', 'Ad_Res_Ind_1_Year', 'Ad_Res_Ind_3_Year', 'Ad_Res_Ind_5_Year', 'Age', 'Cust_Ann_Income']
categorical = ['Status_Cust', 'Status_Latest_Ad', 'Cust_Prop', 'Gender']

# %% [markdown]
# ### Explore Relationship Between Categorical & Target Variable
#
# **Hint**: use `sns.countplot()` plot

# %%
#Your Code Here
df[categorical]
# Out:
#      Status_Cust  Status_Latest_Ad Cust_Prop Gender
# 0              A                 0         H      F
# 1              A                 1         U      M
# 2              S                 1         U      F
# 3              A                 0         U      F
# 4              S                 1         H      F
# ...          ...               ...       ...    ...
# 3613           A                 0         H      F
# 3614           S                 1         H      F
# 3615           A                 1         U      M
# 3616           A                 1         H      M
# 3617           A                 0         U      M
#
# [3618 rows x 4 columns]

# %%
ax = sns.countplot(x='Status_Cust', hue="Potential_Customer", data=df)
ax.set_title('Relationship between Customer Status and Potential Customer')
ax.set_xlabel('Status Customer')
ax.set_xticklabels(["Active", "Star", "Inactive", "First time", "New", "Lapsing"])
plt.show()

# The number of customer who currently make a purchased is slightly lower than those who didn't make any purchased except for star buyer
# The star buyer is greater than other buyer when compared to their own group, who make a purchased currently

# %%
fig, ax = plt.subplots(figsize=(5.5,6))
ax = sns.countplot(x='Status_Latest_Ad', hue="Potential_Customer", data=df)
ax.set_title('Relationship between Customer Response to the Last Promotional Sales and Potential Customer')
ax.set_xlabel('Status Latest Advertisement')
ax.set_xticklabels(['No Purchased', 'Has Purchased'])
plt.show()

# We can see that the most of the customer purchased the goods after seeing the last promotional sales
# There is small group of potential customer who before this didn't make any purchased after seeing the advertisement, but currently they make a purchased
# There is also a large number of customer who before this make a purchased after seeing the advertisement, but currently they didn't make a purchased

# %%
fig, ax = plt.subplots(figsize=(4.5,5))
ax = sns.countplot(x='Cust_Prop', hue="Potential_Customer", data=df)
ax.set_title('Relationship between Customer Housing and Potential Customer')
ax.set_xlabel('Customer Housing')
ax.set_xticklabels(['Owner', 'Unknown'])
plt.show()

# For both customer who has and hadn't make a latest purchased, most of them own their own house

# %%
ax = sns.countplot(x='Gender', hue="Potential_Customer", data=df)
ax.set_title('Relationship between Gender and Potential Customer')
ax.set_xticklabels(['Female', 'Male', 'Unknown'])
plt.show()

# Most of the customer in this shop is from female group either they make any latest purchased or not

# %% [markdown]
# ### Insight

# %%
# The number of customer who currently make a purchased is slightly lower than those who didn't make any purchased except for star buyer
# The star buyer is greater than other buyer when compared to their own group, who make a purchased currently

# There is small group of potential customer who before this didn't make any purchased after seeing the advertisement, but currently they make a purchased
# There is also a large number of customer who before this make a purchased after seeing the advertisement, but currently they didn't make a purchased
# The customer who currently make a purchased is lower than the last customer who make a purchased after seering the advertisement

# Female customer and customer who own their own house are the majority in this shop either they make any latest purchased or not

# %% [markdown]
# ### Solution

# %%
# We can divide the customer into 3 group (active, star and other) and we need to do different promotional strategies to them 
# We need to do effective strategies to attract the attention of customer due to the number of customer who currently make a purchased is lower than before
# The purchasing power is mostly from women and people who own their own house, focus to this group

# %% [markdown]
# ## Explore Numerical Variables
#
# **Hint**: use `sns.distplot()` and `sns.boxplot()`

# %%
df[numerical]
# Out:
#       Cust_Last_Purchase  Pur_3_years  Pur_5_years  Pur_3_years_Indirect  \
# 0                    5.0            2           17                     2
# 1                   30.0            1            7                     0
# 2                    NaN            5           12                     3
# 3                   20.0            1           11                     0
# 4                    5.0            3           15                     2
# ...                  ...          ...          ...                   ...
# 3613                20.0            2            6                     0
# 3614                 NaN            7           31                     4
# 3615                 NaN            7           13                     6
# 3616                 NaN            1           11                     1
# 3617                21.0            3           13                     1
#
#       Pur_5_years_Indirect  Pur_latest  Pur_3_years_Avg  Pur_5_years_Avg  \
# ...

# %%
#Your Code Here
fig, ax = plt.subplots(4, 5, figsize=(20,15))
for variable, subplot in zip(numerical, ax.flatten()):
    sns.distplot(df[variable], ax=subplot)

# %%
fig, ax = plt.subplots(4, 5, figsize=(20,15))
for variable, subplot in zip(numerical, ax.flatten()):
    sns.boxplot(df[variable], ax=subplot)

# %% [markdown]
# ###  Check the skewness and kurtosis of the variables? Is it normal? Document your process in the notebook of handling skewness and kurtosis

# %%
# Skewness used to measure symmetry of data along with the mean value. (-ve , 0 , +ve )
# Kurtosis used to defined peakness or flatness of density plot (-ve flat, 0 , +ve peak)

import scipy.stats as stats

# %% [markdown]
# ### Cust_Last_Purchase

# %%
print("Skewness is", df["Cust_Last_Purchase"].skew()) 
print("Kurtosis is", df["Cust_Last_Purchase"].kurt())
# Out:
# Skewness is 4.96680975014856
# Kurtosis is 51.83974250947104

# %%
stats.probplot(df["Cust_Last_Purchase"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Customer Last Purchase")
plt.show()

#From Q-Q plot and skewness and kurtosis, the Amount of Customer Currently Purchases is not normally distributed (Highly skewed to the right and high peakedness in dataset)

# %% [markdown]
# ### Pur_3_years

# %%
print("Skewness is", df["Pur_3_years"].skew()) 
print("Kurtosis is", df["Pur_3_years"].kurt())
# Out:
# Skewness is 1.2913220920156112
# Kurtosis is 2.1155417837433967

# %%
stats.probplot(df["Pur_3_years"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Number of Purchase in 3 Years")
plt.show()

#From Q-Q plot and skewness and kurtosis, the Number of Purchases in 3 Years is not normally distributed (Skewed to the right)

# %% [markdown]
# ### Pur_5_years

# %%
print("Skewness is", df["Pur_5_years"].skew()) 
print("Kurtosis is", df["Pur_5_years"].kurt())
# Out:
# Skewness is 2.0792958433558395
# Kurtosis is 8.114353477094276

# %%
stats.probplot(df["Pur_5_years"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Number of Purchase in 5 Years")
plt.show()

#From Q-Q plot and skewness and kurtosis, the Number of Purchases in 5 Years is not normally distributed (Skewed to the right)

# %% [markdown]
# ### Pur_3_years_Indirect

# %%
print("Skewness is", df["Pur_3_years_Indirect"].skew()) 
print("Kurtosis is", df["Pur_3_years_Indirect"].kurt())
# Out:
# Skewness is 1.1247687754486253
# Kurtosis is 1.375351281172816

# %%
stats.probplot(df["Pur_3_years_Indirect"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Number of Purchase in 3 Years Indirect")
plt.show()

#From Q-Q plot and skewness and kurtosis, the Number of Purchases in 3 Years (Indirect) is not normally distributed (Skewed to the right)

# %% [markdown]
# ### Pur_5_years_Indirect

# %%
print("Skewness is", df["Pur_5_years_Indirect"].skew()) 
print("Kurtosis is", df["Pur_5_years_Indirect"].kurt())
# Out:
# Skewness is 1.2870714165266253
# Kurtosis is 2.0463520602634224

# %%
stats.probplot(df["Pur_5_years_Indirect"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Number of Purchase in 5 Years Indirect")
plt.show()

#From Q-Q plot and skewness and kurtosis, the Number of Purchases in 5 Years (Indirect) is not normally distributed (Skewed to the right)

# %% [markdown]
# ### Pur_latest

# %%
print("Skewness is", df["Pur_latest"].skew()) 
print("Kurtosis is", df["Pur_latest"].kurt())
# Out:
# Skewness is 6.66011645195726
# Kurtosis is 101.7561516079706

# %%
stats.probplot(df["Pur_latest"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Amount of Latest Purchases")
plt.show()

#From Q-Q plot and skewness and kurtosis, the Amount of Latest Purchases is not normally distributed (Highly skewed to the right with high peakedness of dataset)

# %% [markdown]
# ### Pur_3_years_Avg

# %%
print("Skewness is", df["Pur_3_years_Avg"].skew()) 
print("Kurtosis is", df["Pur_3_years_Avg"].kurt())
# Out:
# Skewness is 7.913836271288157
# Kurtosis is 145.5200139908152

# %%
stats.probplot(df["Pur_3_years_Avg"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Average Amount Purchases in 3 Years")
plt.show()

#From Q-Q plot and skewness and kurtosis, the Average Amount of Purchases in 3 Years is not normally distributed (Highly skewed to the right with high peakedness of dataset)

# %% [markdown]
# ### Pur_5_years_Avg

# %%
print("Skewness is", df["Pur_5_years_Avg"].skew()) 
print("Kurtosis is", df["Pur_5_years_Avg"].kurt())
# Out:
# Skewness is 6.7565794816193225
# Kurtosis is 112.63365682959795

# %%
stats.probplot(df["Pur_5_years_Avg"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Average Amount Purchases in 5 Years")
plt.show()

#From Q-Q plot and skewness and kurtosis, the Average Amount of Purchases in 5 Years is not normally distributed (Highly skewed to the right with high peakedness of dataset)

# %% [markdown]
# ### Pur_3_years_Avg_Indirect

# %%
print("Skewness is", df["Pur_3_years_Avg_Indirect"].skew()) 
print("Kurtosis is", df["Pur_3_years_Avg_Indirect"].kurt())
# Out:
# Skewness is 8.043963470028595
# Kurtosis is 159.3643079980277

# %%
stats.probplot(df["Pur_3_years_Avg_Indirect"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Average Amount Purchases in 3 Years (Indirect)")
plt.show()

#From Q-Q plot and skewness and kurtosis, the Average Amount of Purchases in 3 Years (Indirect) is not normally distributed (Highly skewed to the right with high peakedness of dataset)

# %% [markdown]
# ### InAct_Last

# %%
print("Skewness is", df["InAct_Last"].skew()) 
print("Kurtosis is", df["InAct_Last"].kurt())
# Out:
# Skewness is -0.808273501361896
# Kurtosis is 2.5061728980686384

# %%
stats.probplot(df["InAct_Last"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Inactive Number of Month Since Last Purchased")
plt.show()

#From Q-Q plot and skewness and kurtosis, the Inactive Number of Month Since Last Purchased is not normally distributed (Skewed to the left)

# %% [markdown]
# ### InAct_First

# %%
print("Skewness is", df["InAct_First"].skew()) 
print("Kurtosis is", df["InAct_First"].kurt())
# Out:
# Skewness is 0.1364549965325427
# Kurtosis is -1.1710290394564056

# %%
stats.probplot(df["InAct_First"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Inactive Number of Month Since First Purchased")
plt.show()

#From Q-Q plot and skewness and kurtosis, the Inactive Number of Month Since First Purchased is not normally distributed (Most points not fall in straight line, skewness and kurtosis value closer to 0)

# %% [markdown]
# ### Ad_Res_1_year

# %%
print("Skewness is", df["Ad_Res_1_year"].skew()) 
print("Kurtosis is", df["Ad_Res_1_year"].kurt())
# Out:
# Skewness is 2.788479322802561
# Kurtosis is 10.520904625993905

# %%
stats.probplot(df["Ad_Res_1_year"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Number of Promotional Ads Responded in 1 Year")
plt.show()

#From Q-Q plot and skewness and kurtosis, the Number of Promotional Ads Responded in 1 Year is not normally distributed (Skewed to the right wiith high peakedness)

# %% [markdown]
# ### Ad_Res_3_year

# %%
print("Skewness is", df["Ad_Res_3_Year"].skew()) 
print("Kurtosis is", df["Ad_Res_3_Year"].kurt())
# Out:
# Skewness is 0.32125920659162366
# Kurtosis is 2.1717180684169417

# %%
stats.probplot(df["Ad_Res_3_Year"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Number of Promotional Ads Responded in 3 Year")
plt.show()

# From Q-Q plot and skewness and kurtosis, the Number of Promotional Ads Responded in 3 Year is normally distributed (Most points fall in straight line, skewness and kurtosis value closer to 0)

# %% [markdown]
# ### Ad_Res_5_year

# %%
print("Skewness is", df["Ad_Res_5_Year"].skew()) 
print("Kurtosis is", df["Ad_Res_5_Year"].kurt())
# Out:
# Skewness is 0.401333480771447
# Kurtosis is 0.23560739297598365

# %%
stats.probplot(df["Ad_Res_5_Year"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Number of Promotional Ads Responded in 5 Year")
plt.show()

# From Q-Q plot and skewness and kurtosis, the Number of Promotional Ads Responded in 5 Year is normally distributed (Most points fall in straight line, skewness and kurtosis value closer to 0)

# %% [markdown]
# ### Ad_Res_Ind_1_Year

# %%
print("Skewness is", df["Ad_Res_Ind_1_Year"].skew()) 
print("Kurtosis is", df["Ad_Res_Ind_1_Year"].kurt())
# Out:
# Skewness is 0.9437116388093629
# Kurtosis is 7.3049203923162835

# %%
stats.probplot(df["Ad_Res_Ind_1_Year"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for  Number of Promotional Ads Responded in 1 Year (Indirect)")
plt.show()

# From  Q-Q plot and skewness and kurtosis, the Number of Promotional Ads Responded in 1 Year (Indirect) is not normally distributed (High peakedness with skew to the right)

# %% [markdown]
# ### Ad_Res_Ind_3_Year

# %%
print("Skewness is", df["Ad_Res_Ind_3_Year"].skew()) 
print("Kurtosis is", df["Ad_Res_Ind_3_Year"].kurt())
# Out:
# Skewness is -0.4480072375376903
# Kurtosis is -0.8989529061403054

# %%
stats.probplot(df["Ad_Res_Ind_3_Year"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Number of Promotional Ads Responded in 3 Year (Indirect)")
plt.show()

# From Q-Q plot and skewness and kurtosis, the Number of Promotional Ads Responded in 3 Year (Indirect) is not normally distributed (Most points not fall in straight line, eventhough the skewness and kurtosis value closer to 0)

# %% [markdown]
# ### Ad_Res_Ind_5_Year

# %%
print("Skewness is", df["Ad_Res_Ind_5_Year"].skew()) 
print("Kurtosis is", df["Ad_Res_Ind_5_Year"].kurt())
# Out:
# Skewness is 0.0680449865913782
# Kurtosis is -0.8135420112153229

# %%
stats.probplot(df["Ad_Res_Ind_5_Year"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Number of Promotional Ads Responded in 5 Year (Indirect)")
plt.show()

# From Q-Q plot and skewness and kurtosis, the Number of Promotional Ads Responded in 5 Year (Indirect) is normally distributed (Most points fall in straight line, the skewness and kurtosis value closer to 0)

# %% [markdown]
# ### Age

# %%
print("Skewness is", df["Age"].skew()) 
print("Kurtosis is", df["Age"].kurt())
# Out:
# Skewness is -0.40635434397377235
# Kurtosis is -0.44194719763315415

# %%
stats.probplot(df["Age"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Age")
plt.show()

# From Q-Q plot and skewness and kurtosis, the Age is not normally distributed (Most points not fall in straight line, eventhough the skewness and kurtosis value closer to 0)

# %% [markdown]
# ### Cust_Ann_Income

# %%
print("Skewness is", df["Cust_Ann_Income"].skew()) 
print("Kurtosis is", df["Cust_Ann_Income"].kurt())
# Out:
# Skewness is 0.039825955304305424
# Kurtosis is 0.43897478990720673

# %%
stats.probplot(df["Cust_Ann_Income"], dist="norm", plot=plt)
plt.title("Normal Q-Q plot for Annual Income of Customers")
plt.show()

# From Q-Q plot and skewness and kurtosis, the Annual Income of Customers is normally distributed (Most points fall in straight line except missing value, the skewness and kurtosis value closer to 0)

# %% [markdown]
# ### Insight

# %%
skewness = df[numerical].skew()
kurtosis = df[numerical].kurtosis()

print(skewness, "\n\n", kurtosis)
# Out:
# Cust_Last_Purchase          4.966810
# Pur_3_years                 1.291322
# Pur_5_years                 2.079296
# Pur_3_years_Indirect        1.124769
# Pur_5_years_Indirect        1.287071
# Pur_latest                  6.660116
# Pur_3_years_Avg             7.913836
# Pur_5_years_Avg             6.756579
# Pur_3_years_Avg_Indirect    8.043963
# InAct_Last                 -0.808274
# InAct_First                 0.136455
# Ad_Res_1_year               2.788479
# Ad_Res_3_Year               0.321259
# Ad_Res_5_Year               0.401333
# Ad_Res_Ind_1_Year           0.943712
# Ad_Res_Ind_3_Year          -0.448007
# Ad_Res_Ind_5_Year           0.068045
# Age                        -0.406354
# Cust_Ann_Income             0.039826
# dtype: float64
#
#  Cust_Last_Purchase           51.839743
# Pur_3_years                   2.115542
# Pur_5_years                   8.114353
# Pur_3_years_Indirect          1.375351
# Pur_5_years_Indirect          2.046352
# ...

# %%
# Normally distributed (Most points fall in straight line, skewness and kurtosis value closer to 0) is column :
# - Number of Promotional Ads Responded in 5 Year
# - Number of Promotional Ads Responded in 5 Year (Indirect) 
# - Annual Income of Customers 

# Not normally distributed (The skewness and kurtosis value closer to 0, however most points not fall in straight line) is column :
# - Inactive Number of Month Since First Purchased 
# - Number of Promotional Ads Responded in 3 Year (Indirect)
# - Age

# Not normally distributed (Moderately skewed to the left with peakedness) is column :
# - Inactive Number of Month Since Last Purchased 

# Not normally distributed (Highly skewed to the right with high peakedness) is column :
# - Currently Amount of Purchases 
# - Latest Amount of Purchases 
# - Average Amount of Purchases in 3 Year 
# - Average Amount of Purchases in 5 Year 
# - Average Amount of Purchases in 3 Year (Indirectly)

# Not normally distributed (Highly skewed to the right with peakedness) is column :
# - Number of Purchases in 3 Year 
# - Number of Purchases in 5 Year 
# - Number of Purchases in 3 Year (Indirectly)
# - Number of Purchases in 5 Year (Indirectly)
# - Number of Promotional Ads Responded in 1 Year

# Not normally distributed (Moderately skewed to the right with peakedness) is column :
# - Number of Promotional Ads Responded in 3 Year
# - Number of Promotional Ads Responded in 1 Year (Indirect)

# %% [markdown]
# ## Check the data for missing values?

# %%
#Your Code Here
df.isnull() #True is missing values
# Out:
#       Potential_Customer  Cust_Last_Purchase  Pur_3_years  Pur_5_years  \
# 0                  False               False        False        False
# 1                  False               False        False        False
# 2                  False                True        False        False
# 3                  False               False        False        False
# 4                  False               False        False        False
# ...                  ...                 ...          ...          ...
# 3613               False               False        False        False
# 3614               False                True        False        False
# 3615               False                True        False        False
# 3616               False                True        False        False
# 3617               False               False        False        False
#
#       Pur_3_years_Indirect  Pur_5_years_Indirect  Pur_latest  Pur_3_years_Avg  \
# ...

# %%
# Count all NaN in each column
#Your Code Here
df.isna().sum()
# Out:
# Potential_Customer             0
# Cust_Last_Purchase          1882
# Pur_3_years                    0
# Pur_5_years                    0
# Pur_3_years_Indirect           0
# Pur_5_years_Indirect           0
# Pur_latest                     0
# Pur_3_years_Avg                0
# Pur_5_years_Avg                0
# Pur_3_years_Avg_Indirect     662
# InAct_Last                     0
# InAct_First                    0
# Ad_Res_1_year                  0
# Ad_Res_3_Year                  0
# Ad_Res_5_Year                  0
# Ad_Res_Ind_1_Year              0
# Ad_Res_Ind_3_Year              0
# Ad_Res_Ind_5_Year              0
# Status_Cust                    0
# Status_Latest_Ad               0
# Age                          793
# Gender                         0
# Cust_Prop                      0
# Cust_Ann_Income                0
# dtype: int64

# %%
# Count all NaN in the dataframe (both columns & Rows)
#Your Code Here
print("Total NaN in each columns : " )
print(df.isnull().sum(axis=0))
# Out:
# Total NaN in each columns :
# Potential_Customer             0
# Cust_Last_Purchase          1882
# Pur_3_years                    0
# Pur_5_years                    0
# Pur_3_years_Indirect           0
# Pur_5_years_Indirect           0
# Pur_latest                     0
# Pur_3_years_Avg                0
# Pur_5_years_Avg                0
# Pur_3_years_Avg_Indirect     662
# InAct_Last                     0
# InAct_First                    0
# Ad_Res_1_year                  0
# Ad_Res_3_Year                  0
# Ad_Res_5_Year                  0
# Ad_Res_Ind_1_Year              0
# Ad_Res_Ind_3_Year              0
# Ad_Res_Ind_5_Year              0
# Status_Cust                    0
# Status_Latest_Ad               0
# Age                          793
# Gender                         0
# Cust_Prop                      0
# Cust_Ann_Income                0
# dtype: int64

# %%
print("Total NaN in each rows : " ) 
df.isnull().sum(axis=1)
# Out:
# Total NaN in each rows :
# 0       0
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 3613    1
# 3614    1
# 3615    1
# 3616    1
# 3617    0
# Length: 3618, dtype: int64

# %% [markdown]
# ### How should we handle missing values? (Should we drop the rows? or impute them with values?)

# %%
#Find which columns have missing value
#Your Code Here
df.columns[df.isnull().any()].tolist()
# Out:
# ['Cust_Last_Purchase', 'Pur_3_years_Avg_Indirect', 'Age']

# %% [markdown]
# #### Handling Missing Value for `Cust_Last_Purchase` column

# %%
# Distribution Cust_Last_Purchase with missing value
sns.distplot(df['Cust_Last_Purchase'])

# %%
sns.boxplot(df['Cust_Last_Purchase'])

# %%
#Impute the missing values for Cust_Last_Purchase column
#Your Code Here
missing_col = ['Cust_Last_Purchase']
for i in missing_col:
    df.loc[df.loc[:,i].isnull(),i] = 0

# %%
# Distribution Cust_Last_Purchase without missing value
sns.distplot(df['Cust_Last_Purchase'])

# %%
sns.boxplot(df['Cust_Last_Purchase'])

# %% [markdown]
# #### Handling Missing Value for `Pur_3_years_Avg_Indirect` column

# %%
# Distribution Pur_3_years_Avg_Indirect with missing value
sns.distplot(df['Pur_3_years_Avg_Indirect'])

# %%
sns.boxplot(df['Pur_3_years_Avg_Indirect'])

# %%
#Impute the missing values for Pur_3_years_Avg_Indirect column
#Your Code Here
missing_col = ['Pur_3_years_Avg_Indirect']
for i in missing_col:
    df.loc[df.loc[:,i].isnull(),i] = df.loc[:,i].median()

# %%
# Distribution Pur_3_years_Avg_Indirect without missing value
sns.distplot(df['Pur_3_years_Avg_Indirect'])

# %%
sns.boxplot(df['Pur_3_years_Avg_Indirect'])

# %% [markdown]
# #### Handling Missing Value for `Age` column
#
# Changes for Age is omitted since it is not relevant to change missing value of age to 0.

# %%
# Distribution Age with missing value
sns.distplot(df['Age'])

# %%
sns.boxplot(df['Age'])

# %%
#Impute the missing values for Age column
#Your Code Here
missing_col = ['Age']
for i in missing_col:
    df.loc[df.loc[:,i].isnull(),i] = df.loc[:,i].median()

# %%
df['Age'].mode()
# Out:
# 0    60.0
# dtype: float64

# %%
#Replace the missing values(values lower than 14) for Age column 
#Your Code Here
missing_col = ['Age']
for i in missing_col:
    df.loc[df.loc[:,i]<14,i] = 60

# %%
# Distribution Age without missing value
sns.distplot(df['Age'])

# %%
sns.boxplot(df['Age'])

# %% [markdown]
# #### Handling Missing Value for `Cust_Ann_Income` column

# %%
# Distribution Cust_Ann_Income with missing value
sns.distplot(df['Cust_Ann_Income'])

# %%
sns.boxplot(df['Cust_Ann_Income'])

# %%
#Your Code Here
missing_col = ['Cust_Ann_Income']
for i in missing_col:
    df.loc[df.loc[:,i]==0,i] = df.loc[:,i].median()

# %%
# Distribution Age without missing value
sns.distplot(df['Cust_Ann_Income'])

# %%
sns.boxplot(df['Cust_Ann_Income'])

# %% [markdown]
# #### Handling Missing Value for `Gender` column

# %%
# Distribution Gender with missing value
plt.hist(df['Gender'])
plt.show()

# %%
#Replace the missing values for Gender column
#Your Code Here
missing_col = ['Gender']
for i in missing_col:
    df.loc[df.loc[:,i]=='U',i] = 'F'

# %%
# Distribution Gender without missing value
plt.hist(df['Gender'])
plt.show()

# %% [markdown]
# ### Explore the Relationship between Numerical Variables & Target Variable

# %%
sns.boxplot(y='Potential_Customer', x='Cust_Last_Purchase', orient='h', data=df, linewidth=1)

# When there is value amount in Customer Currently Purchases, potential customer is 1, otherwise potential customer is 0

# %%
sns.boxplot(y='Potential_Customer', x='Pur_3_years', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='Pur_5_years', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='Pur_3_years_Indirect', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='Pur_5_years_Indirect', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='Pur_latest', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='Pur_3_years_Avg', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='Pur_5_years_Avg', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='Pur_3_years_Avg_Indirect', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='InAct_Last', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='InAct_First', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='Ad_Res_1_year', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='Ad_Res_3_Year', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='Ad_Res_5_Year', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='Ad_Res_Ind_1_Year', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='Ad_Res_Ind_3_Year', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='Ad_Res_Ind_5_Year', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='Age', orient='h', data=df, linewidth=1)

# %%
sns.boxplot(y='Potential_Customer', x='Cust_Ann_Income', orient='h', data=df, linewidth=1)

# %% [markdown]
# # <font color=green>Insights through data visualization<font>
#
# ### Create a chart to visualize potential customer breakdown

# %%
#Your Code Here
sns.countplot(x='Potential_Customer', data=df)

# %% [markdown]
# ### How is the Age of the customers distributed? Plot your Answer with the appropriate chart

# %%
#Your Code Here
df.groupby(by='Age').size()
# Out:
# Age
# 14.0     1
# 16.0     2
# 17.0    19
# 19.0     2
# 21.0     1
#         ..
# 83.0    53
# 84.0    32
# 85.0    30
# 86.0    33
# 87.0    34
# Length: 71, dtype: int64

# %%
df.hist('Age');
plt.title('Distribution of Age');
plt.xlabel('Age');

# %% [markdown]
# ### Explore the data by visualizing other features (such as customer annual income, distribution of gender)
# - Start by asking questions that can add value to the business (example: how did my customers behaving lately?)
# - Then continue by identifying which data are needed for the questions to be answered

# %%
sns.countplot(x='Gender', data=df);
plt.title('Distribution of Gender');
plt.show()

# Majority customer is from female

# %%
#Box Plot
sns.boxplot(y='Cust_Ann_Income', x='Gender', data=df);
plt.title('Distribution of Customer Annual Income by Gender');
plt.ylabel('Customer Annual Income');
plt.show()

# On average, male has higher annual income compared to female

# %%
#Bar Plot
sns.barplot(y='Cust_Ann_Income', x='Gender', data=df);
plt.title('Distribution of Customer Annual Income by Gender');
plt.ylabel('Customer Annual Income');
plt.show()

# %% [markdown]
# ### What is the distribution of customers' last purchase

# %%
sns.distplot(df['Cust_Last_Purchase'])
plt.title('Distribution of Customer Current Purchase');
plt.xlabel('Customer Current Purchase ($)');
plt.show()

# %%
sns.distplot(df['Pur_latest'])
plt.title('Distribution of Customer Latest Purchase');
plt.xlabel('Customer Latest Purchase ($)');
plt.show()

# %% [markdown]
# ### What's the Purchase amount pattern with regards to Gender

# %%
#Box Plot
sns.boxplot(y='Cust_Last_Purchase', x='Gender', data=df)
plt.title('Distribution of Customer Current Purchase by Gender');
plt.ylabel('Amount Current Purchase ($)');
plt.show()

# Male have a higher amount current purchase

# %%
#Bar Plot
sns.barplot(y='Cust_Last_Purchase', x='Gender', data=df)
plt.title('Distribution of Customer Current Purchase by Gender');
plt.ylabel('Amount Current Purchase ($)');
plt.show()

# %%
#Box Plot
sns.boxplot(y='Pur_latest', x='Gender', data=df)
plt.title('Distribution of Customer Last Purchase by Gender');
plt.ylabel('Amount Last Purchase ($)');
plt.show()

# Male have a higher amount latest purchase

# %%
#Bar Plot
sns.barplot(y='Pur_latest', x='Gender', data=df)
plt.title('Distribution of Customer Last Purchase by Gender');
plt.ylabel('Amount Last Purchase ($)');
plt.show()

# %% [markdown]
# ### On average, which group of gender has the higher latest purchase amount?

# %%
#Your Code Here
df.groupby(by='Gender')['Cust_Last_Purchase'].mean()

#On average, male has the higher current purchase amount
# Out:
# Gender
# F    6.638051
# M    7.458824
# Name: Cust_Last_Purchase, dtype: float64

# %%
#Your Code Here
df.groupby(by='Gender')['Pur_latest'].mean()

#On average, male has the higher latest purchase amount
# Out:
# Gender
# F    14.792744
# M    15.915033
# Name: Pur_latest, dtype: float64

# %% [markdown]
# ### What is the distribution of the status of our customers

# %%
#Your Code Here
sns.countplot(x='Status_Cust', data=df)
plt.title('Distribution of Customer Status');
plt.xlabel('Customer Status');
plt.show()

# Majority of customer is active buyer (A), follow by star buyer (S), first time buyer (F), new buyer (N), inactive buyer (E) and lastly lapsing buyer (L)

# %% [markdown]
# ### What is the average number of purchase made in the last 3 years among different customer status

# %%
#Your Code Here
df.groupby(by='Status_Cust')['Pur_3_years'].mean()
# Out:
# Status_Cust
# A    2.838304
# E    2.513889
# F    1.164384
# L    2.500000
# N    1.893720
# S    5.214730
# Name: Pur_3_years, dtype: float64

# %%
#Your Code Here
sns.boxplot(y='Pur_3_years', x='Status_Cust', data=df);
plt.title('Distribution of Number of Purchase in 3 Years by Customer Status');
plt.ylabel('Number of Purchase in 3 Years');
plt.xlabel('Customer Status');
plt.show()

# On average, star buyer have highest number of purchases in 3 years, follow by active, inactive, lapsing, new and first time buyer

# %%
#Your Code Here
#Bar Plot
sns.barplot(y='Pur_3_years', x='Status_Cust', data=df);
plt.title('Distribution of Number of Purchase in 3 Years by Customer Status');
plt.ylabel('Number of Purchase in 3 Years');
plt.xlabel('Customer Status');
plt.show()

# %% [markdown]
# ### What is the average number of purchase made in the last 5 years among different customer status

# %%
#Your Code Here
df.groupby(by='Status_Cust')['Pur_5_years'].mean()
# Out:
# Status_Cust
# A     9.102050
# E     7.819444
# F     1.712329
# L    11.800000
# N     2.420290
# S    19.477178
# Name: Pur_5_years, dtype: float64

# %%
#Your Code Here
#Box Plot
sns.boxplot(y='Pur_5_years', x='Status_Cust', data=df);
plt.title('Distribution of Number of Purchase in 5 Years by Customer Status');
plt.ylabel('Number of Purchase in 5 Years');
plt.xlabel('Customer Status');
plt.show()

# On average, star buyer have highest number of purchases in 3 years, follow by lapsing, active, inactive, new and first time buyer

# %%
#Bar Plot
sns.barplot(y='Pur_5_years', x='Status_Cust', data=df);
plt.title('Distribution of Number of Purchase in 5 Years by Customer Status');
plt.ylabel('Number of Purchase in 5 Years');
plt.xlabel('Customer Status');
plt.show()

# %% [markdown]
# ### What is the distribution of the inactive number of months since last purchase?

# %%
#Your Code Here
sns.distplot(df['InAct_Last'])
plt.title('Distribution of Inactive Number of Month Since Last Purchase');
plt.xlabel('Inactive Number of Month Since Last Purchase');
plt.show()

# %% [markdown]
# ### What is the average number of purchase made in the last 3 years among different gender

# %%
#Your Code Here
df.groupby(by='Gender')['Pur_3_years'].mean()
# Out:
# Gender
# F    3.373084
# M    3.220915
# Name: Pur_3_years, dtype: float64

# %%
#Your Code Here
#Box Plot
sns.boxplot(y='Pur_3_years', x='Gender', data=df);
plt.title('Distribution of Number of Purchase in 3 Years by Gender');
plt.ylabel('Number of Purchase in 3 Years');
plt.xlabel('Gender');
plt.show()

# On average, female has the higher number of purchase made in 3 years

# %%
#Your Code Here
#Bar Plot
sns.barplot(y='Pur_3_years', x='Gender', data=df);
plt.title('Distribution of Number of Purchase in 3 Years by Gender');
plt.ylabel('Number of Purchase in 3 Years');
plt.xlabel('Gender');
plt.show()

# %% [markdown]
# ### Check the distribution of customers who responded to ads in past 5 years with By Gender

# %% [markdown]
# #### Plot By gender

# %%
#Your Code Here
df.groupby(by='Gender')['Ad_Res_5_Year'].mean()
# Out:
# Gender
# F    49.492816
# M    49.779085
# Name: Ad_Res_5_Year, dtype: float64

# %%
#Your Code Here
#Box Plot
sns.boxplot(y='Ad_Res_5_Year', x='Gender', data=df);
plt.title('Distribution of Customers who Responded to Ads in Past 5 Years by Gender');
plt.ylabel('Number of Promotional Ads Responded');
plt.xlabel('Gender');
plt.show()

# On average, male has the higher number of promotional ads responded in 5 years

# %%
#Your Code Here
#Bar Plot
sns.barplot(y='Ad_Res_5_Year', x='Gender', data=df);
plt.title('Distribution of Customers who Responded to Ads in Past 5 Years by Gender');
plt.ylabel('Number of Promotional Ads Responded');
plt.xlabel('Gender');
plt.show()

# %% [markdown]
# #### Plot By Customer Status

# %%
#Your Code Here
df.groupby(by='Status_Cust')['Ad_Res_5_Year'].mean()
# Out:
# Status_Cust
# A    49.826654
# E    28.444444
# F    16.634703
# L    60.100000
# N    19.937198
# S    64.477178
# Name: Ad_Res_5_Year, dtype: float64

# %%
#Your Code Here
#Box Plot
sns.boxplot(y='Ad_Res_5_Year', x='Status_Cust', data=df);
plt.title('Distribution of Customers who Responded to Ads in Past 5 Years by Customer Status');
plt.ylabel('Number of Promotional Ads Responded');
plt.xlabel('Customer Status');
plt.show()

# On average, star buyer has the highest number of promotional ads responded in 5 years, follow by lapsing, active, inactive, new and first time buyer

# %%
#Bar Plot
sns.barplot(y='Ad_Res_5_Year', x='Status_Cust', data=df);
plt.title('Distribution of Customers who Responded to Ads in Past 5 Years by Customer Status');
plt.ylabel('Number of Promotional Ads Responded');
plt.xlabel('Customer Status');
plt.show()

# %% [markdown]
# #### Plot By House Ownership

# %%
#Your Code Here
df.groupby(by='Cust_Prop')['Ad_Res_5_Year'].mean()
# Out:
# Cust_Prop
# H    49.395255
# U    49.878436
# Name: Ad_Res_5_Year, dtype: float64

# %%
#Box Plot
sns.boxplot(y='Ad_Res_5_Year', x='Cust_Prop', data=df);
plt.title('Distribution of Customers who Responded to Ads in Past 5 Years by Status of House Ownership');
plt.ylabel('Number of Promotional Ads Responded');
plt.xlabel('Ownership of Houses');
plt.show()

# On average, the unknown status of house ownership has higher of number promotional ads responded in 5 years compared to owner

# %%
#Bar Plot
sns.barplot(y='Ad_Res_5_Year', x='Cust_Prop', data=df);
plt.title('Distribution of Customers who Responded to Ads in Past 5 Years by Status of House Ownership');
plt.ylabel('Number of Promotional Ads Responded');
plt.xlabel('Ownership of House');
plt.show()

# %% [markdown]
# #### Summarize your findings - what have you learned from your insights?

# %%
#Your Code Here
# AGE
# Majority of customer from old people 

# GENDER
# Majority of customer is female (F), but on average, the higher annual income come from male customer
# On average, the higher number of purchases in 3 years is female, but the higher amount purchase current and latest is from male
# On average, male has higher number of promotional ads responded

# %%
# CUSTOMER STATUS
# Majority of customer is active buyer (A), follow by star buyer (S), first time buyer (F), new buyer (N), inactive buyer (E) and lastly lapsing buyer (L)
# On average, star buyer has higher number of purchases in 3 & 5 years, and the higher number of promotional ads responded

# STATUS OF HOUSE OWNERSHIP
# Majority of customer is owner of house (O)
# On average, the unknown status of house ownership has higher of number promotional ads responded in 5 years

# %% [markdown]
# # <font color=green>Feature Enginearing<font>
#
# ### We have too many Features? Do you think you can make some high level features?
#
# For example: Instead of three variables for number of ads responded by customer? why not create a single variable which shows ads responded in last three years

# %%
#Your Code Here
# Yes, too many features in dataset

# %%
#Your Code Here
# Customer Purchasing History
df1 = df[['Pur_3_years', 'Pur_3_years_Avg', 'Ad_Res_3_Year', 'Status_Cust', 'Age', 'Cust_Prop', 'Gender', 'Cust_Ann_Income']]
df2 = df[['Pur_5_years', 'Pur_5_years_Avg', 'Ad_Res_5_Year', 'Status_Cust', 'Age', 'Cust_Prop', 'Gender', 'Cust_Ann_Income']]
df3 =  df[['Potential_Customer', 'Cust_Last_Purchase','Pur_latest', 'Status_Cust', 'Status_Latest_Ad', 'Age', 'Cust_Prop', 'Gender', 'Cust_Ann_Income']]

# %%
#Your Code Here
df['Cust_Ann_Income'].max()
# Out:
# 174305.0

# %%
#Class group Income
#low income < 40 k
#middle income 40 k - 120 k
#upper income > 120 k

bins = [0, 40000, 120000, 180000]
labels = ["Lower Class", "Middle Class", "Upper Class"]
df["Class_Income"] = pd.cut(df['Cust_Ann_Income'], bins = bins, labels=labels)

# %%
df['Ad_Res_3_Year'].max()
# Out:
# 71

# %%
#Frequency ads responded in 3 years
#Rarely < 10
#Sometimes 10 - 20
#Often 20 - 40
#Always > 40

bins = [0, 10, 20, 40, 80]
labels = ["Rarely", "Sometimes", "Often", "Always"]
df["Frequency_Ad_Res_3_Year"] = pd.cut(df['Ad_Res_3_Year'], bins = bins, labels=labels)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3618 entries, 0 to 3617
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Potential_Customer        3618 non-null   int64
#  1   Cust_Last_Purchase        3618 non-null   float64
#  2   Pur_3_years               3618 non-null   int64
#  3   Pur_5_years               3618 non-null   int64
#  4   Pur_3_years_Indirect      3618 non-null   int64
#  5   Pur_5_years_Indirect      3618 non-null   int64
#  6   Pur_latest                3618 non-null   float64
#  7   Pur_3_years_Avg           3618 non-null   float64
#  8   Pur_5_years_Avg           3618 non-null   float64
#  9   Pur_3_years_Avg_Indirect  3618 non-null   float64
#  10  InAct_Last                3618 non-null   int64
#  11  InAct_First               3618 non-null   int64
#  12  Ad_Res_1_year             3618 non-null   int64
# ...

# %% [markdown]
# # <font color=green>Feature Selection<font>
#
# ### Check the correlation among the variables

# %%
#Your Code Here
df.corr()
# Out:
#                           Potential_Customer  Cust_Last_Purchase  Pur_3_years  \
# Potential_Customer                  1.000000            0.672247     0.147106
# Cust_Last_Purchase                  0.672247            1.000000    -0.075162
# Pur_3_years                         0.147106           -0.075162     1.000000
# Pur_5_years                         0.097972           -0.045819     0.557350
# Pur_3_years_Indirect                0.135133           -0.057858     0.842210
# Pur_5_years_Indirect                0.098305           -0.057194     0.540581
# Pur_latest                         -0.101008            0.359298    -0.349252
# Pur_3_years_Avg                    -0.103504            0.272666    -0.355583
# Pur_5_years_Avg                    -0.111500            0.229410    -0.369803
# Pur_3_years_Avg_Indirect           -0.097539            0.222773    -0.310144
# InAct_Last                         -0.103023           -0.011641    -0.237964
# ...

# %%
#Your Code Here (Weak - Moderate - Strong)
# Potential_Customer have strong relationship with Cust_Last_Purchase (the value Potential_Customer is based on Cust_Last_Purchase)
# Potential_Customer, Age, Cust_Ann_Income have very weak relationship with other variables

# We can see that the variables with indirect have very strong relationship with its total value (indirect subset to total, for example Pur_5_years_Indirect with Pur_5_years)
# InAct_First have quite strong relationship with purchasing history in 5 years

# Status_Latest_Ad have moderate strong relationship with purchasing history in 3 & 5 years
# Number of purchased have slightly weak relationship with amount of purchased ($)

# %% [markdown]
# ### Create a Heatmap of correlation between the variables

# %%
#Your Code Here
fig, ax = plt.subplots(figsize=(16,16))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
# The variables from Strong Positive relationship to Moderate Negative Relationship
# Most variables not correlated with each others

# %% [markdown]
# ### Summarize your findings - what have you learned from your insights?

# %%
# When there are too many variables in our dataset, it will become quite messy and hard to understand the important points in correlation
# Check and investigate the dataset whether the variable is highly correlated with other columns or not in real life

# %% [markdown]
# ### Find the Numerical Summary statistics for the variables such as mean, median, mode

# %%
# Take some time to understand these numbers
# Median is row 50%
df.describe()
# Out:
#        Potential_Customer  Cust_Last_Purchase  Pur_3_years  Pur_5_years  \
# count         3618.000000         3618.000000  3618.000000  3618.000000
# mean             0.479823            6.985144     3.308734    11.018795
# std              0.499662           10.820356     2.185492     9.405537
# min              0.000000            0.000000     0.000000     1.000000
# 25%              0.000000            0.000000     2.000000     4.000000
# 50%              0.000000            0.000000     3.000000     9.000000
# 75%              1.000000           11.000000     4.000000    15.000000
# max              1.000000          200.000000    15.000000    91.000000
#
#        Pur_3_years_Indirect  Pur_5_years_Indirect   Pur_latest  \
# count           3618.000000           3618.000000  3618.000000
# mean               1.909066              5.887507    15.267344
# std                1.624995              4.904147    10.794970
# min                0.000000              0.000000     0.000000
# ...

# %%
df.mode()
# Out:
#    Potential_Customer  Cust_Last_Purchase  Pur_3_years  Pur_5_years  \
# 0                   0                 0.0            2            1
#
#    Pur_3_years_Indirect  Pur_5_years_Indirect  Pur_latest  Pur_3_years_Avg  \
# 0                     1                     1        15.0             15.0
#
#    Pur_5_years_Avg  Pur_3_years_Avg_Indirect  ...  Ad_Res_Ind_3_Year  \
# 0             15.0                     11.67  ...                 15
#
#    Ad_Res_Ind_5_Year  Status_Cust  Status_Latest_Ad   Age  Gender  Cust_Prop  \
# 0                 23            A                 1  60.0       F          H
#
#    Cust_Ann_Income  Class_Income  Frequency_Ad_Res_3_Year
# 0          44284.5  Middle Class                    Often
#
# [1 rows x 26 columns]

# %% [markdown]
# ### Check for outliers by either plotting box plots or IQR For all numerical variables

# %%
#Your Code Here
fig, ax = plt.subplots(4, 5, figsize=(20,15))
for variable, subplot in zip(numerical, ax.flatten()):
    sns.boxplot(df[variable], ax=subplot)

# %%
#Your Code Here
# Only variable Ad_Res_Ind_3_Year didn't have outlier
# The outlier in amount of purchases (currently, latest, 3 & 5 years) have the huge gap, so the box plot look quite small
# We cann't remove outliers without solid reason because outliers are important in our dataset

# %% [markdown]
# ### Pandas to SQL
#
# #### Load the data into a Sql database, customers
# Hint: Create database with name Customers
# Use pandas to connect and load the dataframe to DATABASE

# %%
#Your Code Here
df.to_csv('Modified Data.csv', index=False)

# %%
import sqlite3

conn = sqlite3.connect('Customers.db')
c = conn.cursor() #The database will be saved in the location where your 'py' file is saved

c.execute('CREATE TABLE CUSTOMER ([C_ID] integer, [Potential_Customer] integer, [Cust_Last_Purchase] integer, [Pur_3_years] integer, [Pur_5_years] integer, [Pur_3_years_Indirect] integer, [Pur_5_years_Indirect] integer, [Pur_latest] integer, [Pur_3_years_Avg] integer, [Pur_5_years_Avg] integer, [Pur_3_years_Avg_Indirect] integer, [InAct_Last] integer, [InAct_First] integer, [Ad_Res_1_year] integer, [Ad_Res_3_Year] integer, [Ad_Res_5_Year] integer, [Ad_Res_Ind_1_Year] integer, [Ad_Res_Ind_3_Year] integer, [Ad_Res_Ind_5_Year] integer, [Age] integer, [Cust_Ann_Income] integer, [Status_Cust] text, [Status_Latest_Ad] integer, [Cust_Prop] text, [Gender] text, [Class_Income] text, [Frequency_Ad_Res_3_Year] text)') #Create table = CUSTOMER
conn.commit()

read_csv = pd.read_csv(r'C:\Users\Home\Desktop\Apprenticeship Transition Program\Project\Modified Data.csv')
read_csv.to_sql('CUSTOMER', conn, if_exists='append', index=False) #Insert values from csv file into the table 'CUSTOMER'

# %%
# %load_ext sql
# %sql sqlite:///Customers.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ### Once you have created a database, use either SQL or Python to query the data and solve these questions

# %%
# %sql SELECT count(*) FROM CUSTOMER;
# Out:
#  * sqlite:///Customers.db
# Done.
# [(3618,)]

# %% [markdown]
# ### Write a query that returns:

# %% [markdown]
# #### a) What percentage of female customers own a house?

# %%
# %sql select Cust_Prop, count(*), count(*)*100 / 3618 as Percentage from CUSTOMER group by Cust_Prop
# Out:
#  * sqlite:///Customers.db
# Done.
# [('H', 1981, 54), ('U', 1637, 45)]

# %%
# %sql select Cust_Prop, Gender, count(*), count(*)*100 / 3618 as Percentage from CUSTOMER where Cust_Prop = 'H' group by Gender
# Out:
#  * sqlite:///Customers.db
# Done.
# [('H', 'F', 1065, 29), ('H', 'M', 916, 25)]

# %% [markdown]
# #### b) How much is the average salary of these customers?

# %%
#Your Code Here
# %sql SELECT round(avg(Cust_Ann_Income),2) as [Average Annual Salary] FROM CUSTOMER;
# Out:
#  * sqlite:///Customers.db
# Done.
# [(50519.65,)]

# %%
#Your Code Here
# %sql SELECT round(sum(Cust_Ann_Income/12)/3618, 2) as [Average Monthly Salary] FROM CUSTOMER;
# Out:
#  * sqlite:///Customers.db
# Done.
# [(4209.6,)]

# %% [markdown]
# ### Write a query that returns:

# %% [markdown]
# #### a) What percentage of purchases are made through external links (indirect buys)?

# %%
# %sql SELECT sum(Pur_3_years_Indirect)*100/sum(Pur_3_years) as [Percentage of Indirect Purchases] FROM CUSTOMER;
# Out:
#  * sqlite:///Customers.db
# Done.
# [(57,)]

# %% [markdown]
# #### b) How many purchases have been made by new buyers through external links?

# %%
#Your Code Here
# %sql SELECT Status_Cust, sum(Pur_3_years_Indirect) as [Purchases Indirect in 3 Years], sum(Pur_5_years_Indirect) as [Purchases Indirect in 5 Years] FROM CUSTOMER WHERE Status_Cust = 'N'
# Out:
#  * sqlite:///Customers.db
# Done.
# [('N', 277, 304)]

# %% [markdown]
# ### Write a query that calculate:

# %% [markdown]
# #### The average amount of purchases that have been made by Star Buyers?

# %%
#Your Code Here
# %sql SELECT Status_Cust, round(avg(Pur_latest),4) as [Average Purchases by Star Buyer] FROM CUSTOMER WHERE Status_Cust='S'
# Out:
#  * sqlite:///Customers.db
# Done.
# [('S', 10.5337)]

# %%
conn.close()
